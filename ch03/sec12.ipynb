# %% [markdown]
# # 3-12. Applications of Diagonalization

# %% [markdown]
# ### Problem 1. Matrix Form of the Coupled Equations
# Multiplying the matrix equation gives exactly the two scalar equations, one for each displacement component.

# %% [markdown]
# ### Problem 2. Principal Axes for a Conic
# The quadratic-form eigenvalues are $3$ and $-2$, so the principal-axis equation is $\boxed{3u^2-2v^2=24}$, a hyperbola.

# %% [markdown]
# ### Problem 3. Rank-One Conic
# The eigenvalues are $10$ and $0$, giving $\boxed{10u^2=35}$. This is a pair of parallel lines in principal coordinates.

# %% [markdown]
# ### Problem 4. Rectangular Hyperbola
# The eigenvalues are $5$ and $-5$, so $\boxed{u^2-v^2=8/5}$.

# %% [markdown]
# ### Problem 5. Quadric Surface
# The eigenvalues are $1,3,6$, so the principal-axis form is $\boxed{u^2+3v^2+6w^2=14}$, an ellipsoid.

# %% [markdown]
# ### Problem 6. Indefinite Quadric
# The eigenvalues are $-\sqrt3,\sqrt3,3$, giving $-\sqrt3\,u^2+\sqrt3\,v^2+3w^2=12$, a hyperboloid.

# %% [markdown]
# ### Problem 7. Another Quadric
# The eigenvalues are $-1,3,5$, so $-u^2+3v^2+5w^2=60$, a hyperboloid of one sheet.

# %% [markdown]
# ### Problem 8. Orthogonality of the Rotation Matrix
# The eigenvectors in the example are normalized and mutually orthogonal; putting them into $C$ gives $C^TC=I$.

# %% [markdown]
# ### Problem 9. Rotation Matrices for Problems 2-7
# For each quadratic form, place an orthonormal eigenbasis as the columns of $C$. Then $C^TMC$ is the diagonal matrix listed in Problems 2-7.

# %% [markdown]
# ### Problem 10. Checking the Normal-Mode Algebra
# Substitution of the trial normal mode reduces the equations to the displayed determinant. Solving it gives the stated eigenvalues, and substituting each eigenvalue gives the listed mode vector.

# %% [markdown]
# ### Problem 11. Example 4 Verification
# Carry out the same determinant and eigenvector computation; the normal modes are the eigenvectors of the mass-weighted spring matrix.

# %% [markdown]
# ### Problem 12. Example 5 Verification
# After forming the coefficient matrix, the characteristic determinant factors as in the text. The corresponding eigenvectors give the stated modes.

# %% [markdown]
# ### Problem 13. Example 6 Verification
# The details reduce to diagonalizing the symmetric vibration matrix; the orthogonal eigenvectors decouple the equations.

# %% [markdown]
# ### Problem 14. Two-Mass Frequencies
# For the spring constants $k,2k,k$ and equal masses, $\omega^2=(k/m)\{1,5\}$ with modes proportional to $(1,1)$ and $(1,-1)$.

# %% [markdown]
# ### Problem 15. Two-Mass Frequencies
# $\omega^2=(k/m)\{3,8\}$ with representative modes $(1,2)$ and $(2,-1)$.

# %% [markdown]
# ### Problem 16. Two-Mass Frequencies
# $\omega^2=(k/m)\{2,7\}$ with representative modes $(1,2)$ and $(2,-1)$.

# %% [markdown]
# ### Problem 17. Unequal-Mass Frequencies
# Using $M^{-1}K$, the eigenvalues are $\omega^2=(k/m)\{2/3,2\}$ after factoring the common mass scale; the eigenvectors give the relative amplitudes.

# %% [markdown]
# ### Problem 18. Unequal-Mass Frequencies
# The mass-weighted matrix gives $\omega^2=(k/m)\{2,16/5\}$, with modes from the corresponding eigenvectors.

# %% [markdown]
# ### Problem 19. Another Unequal-Mass System
# The eigenvalues are $\omega^2=(k/m)\{3/2,3\}$ in the chosen common units.

# %% [markdown]
# ### Problem 20. Example 7 Details
# Set up the two coupled equations, form the determinant for $\omega^2$, and solve for the two characteristic modes exactly as in the preceding examples.

# %% [markdown]
# ### Problem 21. Vertical Two-Mass Array
# The model matrix gives eigenvalues proportional to $1$ and $6$, so $\omega=\sqrt{k/m}$ and $\sqrt{6k/m}$ with the associated eigenmodes.

# %% [markdown]
# ### Problem 22. Second Vertical Array
# The characteristic values are proportional to $2/3$ and $2$ after mass weighting.

# %% [markdown]
# ### Problem 23. Third Vertical Array
# The characteristic values are proportional to $1/4$ and $1$ after mass weighting.
