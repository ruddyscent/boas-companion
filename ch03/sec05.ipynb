# %% [markdown]
# # 3-5. Lines and Planes

# %% [markdown]
# ### Problem 1. Line Through a Point with Given Slope
# A direction vector with slope $3/4$ is $(4,3)$. Thus $r=(2,-3)+t(4,3)$.

# %% [markdown]
# ### Problem 2. Slope from Parametric Form
# The direction vector is $(2,3)$, so the slope is $\boxed{3/2}$.

# %% [markdown]
# ### Problem 3. Line Through Two Points
# The direction vector is $(2,2)$, so $r=(1,-2)+t(2,2)$.

# %% [markdown]
# ### Problem 4. Perpendicular Line in the Plane
# The given direction is $(1,-2)$, so a perpendicular direction is $(2,1)$. Hence $r=(1,0)+t(2,1)$.

# %% [markdown]
# ### Problem 5. The y-axis
# A parametric form is $r=(0,0)+t(0,1)$.

# %% [markdown]
# ### Problem 6. Line Equations
# The symmetric description is $(x-1)/1=(y+1)/(-2)=(z+5)/2$, and a parametric form is $(x,y,z)=(1,-1,-5)+t(1,-2,2)$.

# %% [markdown]
# ### Problem 7. Line Equations
# The symmetric description is $(x-2)/3=(y-3)/(-2)=(z-4)/(-6)$, and a parametric form is $(x,y,z)=(2,3,4)+t(3,-2,-6)$.

# %% [markdown]
# ### Problem 8. Line Equations
# The symmetric description is $y=-2$ and $x/3=(z-4)/(-5)$, and a parametric form is $(x,y,z)=(0,-2,4)+t(3,0,-5)$.

# %% [markdown]
# ### Problem 9. Line Equations
# The symmetric description is $x=-1$ and $z=7$, and a parametric form is $(x,y,z)=(-1,3,7)+t(0,-5,0)$.

# %% [markdown]
# ### Problem 10. Line Equations
# The symmetric description is $(x-3)/2=(y-4)/(-3)=(z+1)/6$, and a parametric form is $(x,y,z)=(3,4,-1)+t(2,-3,6)$.

# %% [markdown]
# ### Problem 11. Line Equations
# The symmetric description is $y=-1$ and $(x-4)/1=(z-3)/(-2)$, and a parametric form is $(x,y,z)=(4,-1,3)+t(1,0,-2)$.

# %% [markdown]
# ### Problem 12. Line Equations
# The symmetric description is direction $(5,-2,1)$ through $(5,-4,2)$, and a parametric form is $(x,y,z)=(5,-4,2)+t(5,-2,1)$.

# %% [markdown]
# ### Problem 13. Line Equations
# The symmetric description is direction $(0,-3,1)$ through $(3,0,-5)$, and a parametric form is $(x,y,z)=(3,0,-5)+t(0,-3,1)$.

# %% [markdown]
# ### Problem 14. Plane Equation
# Use a cross product for the normal vector. A simplified equation is $-36x+3y+22z=-23$.

# %% [markdown]
# ### Problem 15. Plane Equation
# Use a cross product for the normal vector. A simplified equation is $5x+6y+3z=0$.

# %% [markdown]
# ### Problem 16. Plane Equation
# Use a cross product for the normal vector. A simplified equation is $5x-2y+z=35$.

# %% [markdown]
# ### Problem 17. Plane Equation
# Use a cross product for the normal vector. A simplified equation is $-3y+z=-5$.

# %% [markdown]
# ### Problem 18. Plane Equation
# Use a cross product for the normal vector. A simplified equation is $x+6y+7z=-5$.

# %% [markdown]
# ### Problem 19. Plane Equation
# Use a cross product for the normal vector. A simplified equation is $x+y+3z=-12$.

# %% [markdown]
# ### Problem 20. Plane Equation
# Use a cross product for the normal vector. A simplified equation is $-x+4y+z=5$.

# %% [markdown]
# ### Problem 21. Angle Between Two Planes
# The normals have dot product $25$ and squared lengths $49$ and $30$, so $\cos\theta=25/(7\sqrt{30})$.

# %% [markdown]
# ### Problem 22. Angle Between Two Planes
# The normals give $\cos\theta=14/(7\sqrt6)=2/\sqrt6$.

# %% [markdown]
# ### Problem 23. Angle Between Two Planes
# The normals give $\cos\theta=4/(3\cdot7)=4/21$.

# %% [markdown]
# ### Problem 24. Intersection Line and Distance
# One point is $(2,0,-2)$ and a direction vector is $(0,-1,-2)$. Thus $r=(2,0,-2)+t(0,-1,-2)$, and the distance from the origin is $\boxed{2\sqrt{30}/5}$.

# %% [markdown]
# ### Problem 25. Intersection Line and Distance
# One point is $(0,-17/4,1/4)$ with direction $(4,9,-1)$. The distance from $(2,1,-1)$ to the line is $\boxed{3\sqrt3/7}$.

# %% [markdown]
# ### Problem 26. Intersection Line and Distance
# One point is $(0,-1/7,-11/7)$ with direction $(-14,-2,-15)$. The distance from $(1,0,0)$ is $\boxed{\sqrt{2/17}}$.

# %% [markdown]
# ### Problem 27. Plane Perpendicular to Two Planes
# A normal is the cross product of the two given plane normals, $(0,-13,-26)$. Through $(2,3,-2)$ this gives $y+2z=-1$.

# %% [markdown]
# ### Problem 28. Another Perpendicular Plane
# The normal is $(4,9,-1)$; through $(-4,-1,2)$ the plane is $\boxed{4x+9y-z=-27}$.

# %% [markdown]
# ### Problem 29. Point and Distance to a Plane
# A point on the plane is $(13/2,0,0)$. The distance from $(7,1,-2)$ is $|2|/\sqrt6=\boxed{2/\sqrt6}$.

# %% [markdown]
# ### Problem 30. Distance from Origin to a Plane
# The distance is $|7|/\sqrt{3^2+(-2)^2+(-6)^2}=\boxed{1}$.

# %% [markdown]
# ### Problem 31. Point-Plane Distance
# The numerator is $|-5|$ and the normal length is $7$, so the distance is $\boxed{5/7}$.

# %% [markdown]
# ### Problem 32. Another Point-Plane Distance
# The numerator is $10$ and the normal length is $3\sqrt3$, so the distance is $\boxed{10/(3\sqrt3)}$.

# %% [markdown]
# ### Problem 33. Distance Between Parallel Lines
# Using $|(P-Q)\times d|/|d|$ gives $\boxed{\sqrt{43/15}}$.

# %% [markdown]
# ### Problem 34. Distance Between Parallel Lines
# The same formula gives $\boxed{\sqrt{11/10}}$.

# %% [markdown]
# ### Problem 35. Distance from Point to Line
# $|(Q-P)\times d|/|d|=\sqrt{245}/7=\boxed{\sqrt5}$.

# %% [markdown]
# ### Problem 36. Another Point-Line Distance
# The cross product has squared length $45$ and $|d|^2=5$, so the distance is $\boxed{3}$.

# %% [markdown]
# ### Problem 37. Intersection Test for Two Lines
# The scalar triple product is zero and the direction vectors are not parallel, so the lines intersect.

# %% [markdown]
# ### Problem 38. Angle Between Lines
# The direction vectors have dot product $21$ and squared lengths $14$ and $33$, so the acute angle satisfies $\cos\theta=21/\sqrt{462}$.

# %% [markdown]
# ### Problem 39. Intersecting Lines and Acute Angle
# The scalar triple product is zero, so the lines meet. The acute angle satisfies $\cos\theta=5/\sqrt{60}$.

# %% [markdown]
# ### Problem 40. Second Intersecting-Line Angle
# The scalar triple product is zero. The acute angle satisfies $\cos\theta=5/\sqrt{39}$.

# %% [markdown]
# ### Problem 41. Distance Between Skew Lines
# The distance is $|[(P_2-P_1)\cdot(d_1\times d_2)]|/|d_1\times d_2|=\boxed{\sqrt{14}}$.

# %% [markdown]
# ### Problem 42. Distance Between Two Joining Lines
# The distance is $\boxed{1/\sqrt5}$.

# %% [markdown]
# ### Problem 43. Distance Between Lines in Symmetric Form
# After converting to parametric form, the scalar triple product formula gives $\boxed{20/\sqrt{21}}$.

# %% [markdown]
# ### Problem 44. Distance from x-axis to a Line
# The same formula gives $\boxed{1/\sqrt{10}}$.

# %% [markdown]
# ### Problem 45. Closest Approach to the Origin
# Take $r_0=(3,-1,1)$ and $A=(2,-2,1)$. Then $t_0=-(r_0\cdot A)/|A|^2=-1$, and the closest distance is $\boxed{\sqrt2}$.
